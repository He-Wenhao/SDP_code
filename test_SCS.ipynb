# %% [markdown]
# # Error subspace SDP
#
# In this ipynb file, we implement SDP for optimal recovery. We consider entanglement fidelity
# \begin{align}
# F_{\mathcal{N}_\gamma, \mathcal{R}}=\left\langle\Psi\left|\left(\mathcal{R} \circ \mathcal{N}_\gamma\right) \otimes \mathcal{I}(|\Psi\rangle\langle\Psi|)\right| \Psi\right\rangle.
# \end{align}
#
# SDP gives the optimal recodery
# \begin{align}
# F_{\mathcal{N}_\gamma, \mathcal{R}_{\mathrm{op}}}=\max _{\mathcal{R}}\left\langle\Psi\left|\left(\mathcal{R} \circ \mathcal{N}_\gamma\right) \otimes \mathcal{I}(|\Psi\rangle\langle\Psi|)\right| \Psi\right\rangle
# \end{align}
#
# Our implementation has following features:
#
# 1. the SDP has only one input: the QEC matrix.
#
# 2. the choi matrix is restricted on the error subspace. As a result, the choi matrix is $l*d*d$ dimensional, where l is the number of Kraus operators taken into consideration, $d=2$ for qubit code.
#
# Also, we provide the results of transpose channel.
# \begin{align}
# \mathcal{R}_T(\cdot) \equiv \sum_i P E_i^{\dagger} \mathcal{N}_\gamma(P)^{-1 / 2}(\cdot) \mathcal{N}_\gamma(P)^{-1 / 2} E_i P
# \end{align}
# Tranpose fidelity can serve as an approximation to the optimal fidelity, and transpose channel(in choi matrix form) serves as a good guess to optimized channel.
#
# # Next step
#
# 1. use transpose channel as an initial guess to speed up solving SDP.
# 2. when iterate through gamma = np.linspace(0,0.1,11), use previous result as initial guess.

# %% [markdown]
# ## Description of changes
# The SCS package allows us to explicitly give a warm start for the variables $x$, $y$ and $s$ for optimization problems framed as follows.
# \begin{split}\begin{array}{lcr}
# \begin{array}{ll}
# \mbox{minimize} & (1/2)x^\top  P x + c^\top  x\\
# \mbox{subject to} &  Ax + s = b\\
#   & s \in \mathcal{K}
# \end{array}
# &\quad&
# \begin{array}{ll}
# \mbox{maximize} & -(1/2)x^\top  P x - b^\top  y\\
# \mbox{subject to} &  Px + A^\top y + c = 0\\
#   & y \in \mathcal{K}^*
# \end{array}
# \end{array}\end{split}
#
# The variable $x = \text{vec}(M_{\mathcal{R}})$ is a flattened vector representing the choi matrix and the function $\texttt{vec}$ maps positive semidefinite matrices to a vector. The constraints of having $\mathcal{R}$ be CPTP can be encoded in $A$ which gives $A$ to be a $(n+k)\times n$ matrix where $k = d^2L^2$ and $n = d^2L(d^2L+1)/2$ and this sets the variable $s$ to be a $n+k$ component vector with the first $k$ components being 0 and the next $n$ being in the semidefinite cone of $\mathbb{R}^n$ which are in fact nothing but the components of $x$ itself.
#
# The warm start functionality of SCS requires that all of $x$, $y$ and $s$ are given. The transpose recovery channel gives us an explicit form for $x$ and by extension $s$ as well. Using the fact that for our problem $P = 0$, the constraint $A^Ty + c = 0$ along with the KKT condition that $y\perp s$, we can get a possible guess for $y$ which minimizes the duality gap. The issue however is that this guess is not guaranteed to be in the cone $\mathcal{K}^*$ which means that the objective for the first iteration is indeed that of the transpose recovery, but it is not even close to satisfying the convergence conditions for SCS.

# %%
import numpy as np
from QECmat_GKP import QECmat_GKP
import cvxpy as cp
import scipy
from scipy import sparse
import scs
import matplotlib.pyplot as plt
from process_QECmat_SCS import process_QECmat

# %%
# The vec function as documented in api/cones
def vec(S):
    n = S.shape[0]
    S = np.copy(S)
    S *= np.sqrt(2)
    S[range(n), range(n)] /= np.sqrt(2)
    return S[np.triu_indices(n)]


# The mat function as documented in api/cones
def mat(s):
    n = int((np.sqrt(8 * len(s) + 1) - 1) / 2)
    S = np.zeros((n, n))
    S[np.triu_indices(n)] = s / np.sqrt(2)
    S = S + S.T
    S[range(n), range(n)] /= np.sqrt(2)
    return S

# %% [markdown]
# # Construct QEC matrix
# Here we use Gaussian envelope finite energy GKP code under pure loss as an example, we use the series expansion algorithm.
#
# You can substitute it for other codes. The QEC matrix $M_{l,\mu,l',\mu'}$ should align as following(here we assume qubit code, and Kraus truncated by L):
#
# $\left(\begin{array}{cccc}M_{00,00} & M_{00,01} & . . & M_{00,L1} \\ M_{01,00} & M_{01,01} & . . & M_{01,L1} \\ & & . . & . . \\ . . & . . & . \\ M_{L1,00} & M_{L 1,01} & . . & M_{L1,L1}\end{array}\right)$

# %%
####################
# calculate QEC matrix for GKP
####################
gamma = 0.05    # pure loss rate
Delta = 0.481   # 1/2 Delta^2 \approx photon number
l_cut = 20      # number of Kraus operator taken into consideration
m_sum_cutoff=20 # accuracy order of basis overlap
M_sum_cutoff=5  # accuracy order of QEC matrix

# calculate GKP QEC matrix, with orthonormal code basis
M_GKP = QECmat_GKP(Delta = Delta, gamma = gamma, l_cut = l_cut, m_sum_cutoff = m_sum_cutoff, M_sum_cutoff = M_sum_cutoff).orth_M()

# %% [markdown]
# # tranpose channel
#
# According to our calculation, entanglement fidelity given by transpose channel is
# \begin{align}
# F_{\mathcal{N}_\gamma, \mathcal{R}_T}=\frac{1}{4} \sum_{l, l^{\prime}}\left(\sum_\mu\left(\left(M^{\perp}\right)^{\frac{1}{2}}\right)_{l, \mu, l^{\prime}, \mu}\right)^2,
# \end{align}
# where $M^{\perp}$ is the error correction matrix in orthonormal basis(which we denote as $M$ in following sections). The choi matrix of $\mathcal{R}_T$ reads
# \begin{align}
# (C_{\mathcal{R}_T})_{\nu,\nu';l,\mu,l',\mu'} = \delta_{l,l'}\delta_{\mu,\nu}\delta_{\mu',\nu'}
# \end{align}
# in our problem setting.
#
# ## code implementation
# In our code, initialization method of
# ```ruby
# class process_QECmat
# ```
# takes matrix $M$ as an input,  method
# ```ruby
#     def transpose_infid_M(self)
# ```
# calculates the infidelity according to our formula, and method
# ```ruby
#     def tranpose_choi(self)
# ```
# calculates the choi matrix given by transpose recovery.
#
# To test the consistency, we show that infidelity given by our expression and by transpose choi matrix are the same.

# %%
####################
# calculate transpose results
####################
GKP_QECprocess = process_QECmat(QECmat = M_GKP,dimL = l_cut,d = 2)  # input GKP QEC matrix

# calculate transpose fidelity result directly
trans_infid = GKP_QECprocess.transpose_infid_M()
print('transpose infid direct:',trans_infid)

# calculate transpose choi matrix, and test consistency
trans_choi = GKP_QECprocess.transpose_choi()
prob0 = GKP_QECprocess.SDP_set_prob()  # setup SDP problem
prob0.variables()[0].save_value(trans_choi)# feed choi into the variable
print('transpose infid by choi:',1-prob0.objective.value)
# Out:
# ------------------------------------------------------------------
# 	       SCS v3.2.3 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 3240, constraints m: 4840
# cones: 	  z: primal zero / dual free vars: 1600
# 	  s: psd vars: 3240, ssize: 1
# settings: eps_abs: 1.0e-06, eps_rel: 1.0e-06, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 4880, nnz(P): 0
# transpose infid direct: 0.005356332498326899
# transpose infid by choi: 0.00535633249832701

# %% [markdown]
# # SDP optimization
#
# We can prove that SDP for optimal recovery channel can be written as
# \begin{align}
# &\max_{C_{\mathcal{R}}}\sum_{i,i',\mu,\mu',\nu,\nu'} (C_{\mathcal{R}})_{\nu,\nu';i,\mu,i',\mu'}K_{\nu,\nu';i,\mu,i',\mu'}, \\
# &(C_{\mathcal{R}})_{\nu,\nu';i,\mu,i',\mu'} \ge 0, \\
# &\sum_{\nu}(C_{\mathcal{R}})_{\nu,\nu;i,\mu,i',\mu'} = I_{i,\mu,i',\mu'},
# \end{align}
# where $I$ is the identity matrix,  $K_{\nu,\nu';i,\mu,i',\mu'} = \sum_{i_0,\mu_0,\nu_0}(M^{1/2})_{\nu,\nu_0;i,\mu,i_0,\mu_0}(M^{1/2})_{\mu_0,\nu';i_0,\nu_0,i',\mu'}$, and $(C_{\mathcal{R}})_{\nu,\nu';i,\mu,i',\mu'} \ge 0$ means that matrix $(C_{\mathcal{R}})_{\nu,\nu';i,\mu,i',\mu'} $ is positive semi definite with $(\nu,i,\mu)$ as row index, and $(\nu',i',\mu')$ as column index. (in principal, these $M^{1/2}$ can be cholesky decomposition, with which can reduce a factor of constant conplexity. But here we use square root for simplicity.)
#
#
# ## code implementation
#
# Method
# ```ruby
#     def SDP_set_prob(self)
# ```
# sets up the SDP problem and returns it. Using solve method in cvxpy, the problem will be solved.

# %%
####################
# SDP optimization using cvxpy
####################

prob1 = GKP_QECprocess.SDP_set_prob()  # setup SDP problem
prob1.solve(solver="SCS",eps=1e-6,verbose = True, warm_start=True)   # solve SDP
print('infid by SDP:',1-prob1.value,'iter:',prob1._solver_stats.num_iters)
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Oct 24 12:04:58 AM: Your problem has 6400 variables, 1601 constraints, and 0 parameters.
# (CVXPY) Oct 24 12:04:58 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 24 12:04:58 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 24 12:04:58 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 24 12:04:58 AM: Compiling problem (target solver=SCS).
# (CVXPY) Oct 24 12:04:58 AM: Reduction chain: FlipObjective -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Oct 24 12:04:58 AM: Applying reduction FlipObjective
# (CVXPY) Oct 24 12:04:58 AM: Applying reduction Dcp2Cone
# (CVXPY) Oct 24 12:04:58 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 24 12:04:58 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Oct 24 12:05:00 AM: Applying reduction SCS
# (CVXPY) Oct 24 12:05:00 AM: Finished problem compilation (took 2.311e+00 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 24 12:05:00 AM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.3 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 3240, constraints m: 4840
# cones: 	  z: primal zero / dual free vars: 1600
# 	  s: psd vars: 3240, ssize: 1
# settings: eps_abs: 1.0e-06, eps_rel: 1.0e-06, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 6440, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2
#   3750| 4.39e-06  8.46e-06  7.20e-06 -9.95e-01  1.00e-01  2.05e+01
#   4000| 4.49e-06  8.46e-06  7.36e-06 -9.95e-01  1.00e-01  2.18e+01
#   4250| 4.59e-06  8.46e-06  7.53e-06 -9.95e-01  1.00e-01  2.32e+01
#   4500| 4.69e-06  8.46e-06  7.69e-06 -9.95e-01  1.00e-01  2.45e+01
#   4750| 4.79e-06  8.46e-06  7.86e-06 -9.95e-01  1.00e-01  2.57e+01
#   5000| 4.00e-06  8.46e-06  6.56e-06 -9.95e-01  1.00e-01  2.70e+01
#   5250| 2.77e-06  4.49e-06  4.20e-06 -9.95e-01  1.00e-01  2.83e+01
#   5500| 8.06e+00  8.73e-01  3.43e-05 -9.95e-01  1.00e-01  2.97e+01
#   5750| 2.61e-07  9.07e-07  5.24e-07 -9.95e-01  1.00e-01  3.10e+01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 3.10e+01s = setup: 6.65e-03s + solve: 3.10e+01s
# 	 lin-sys: 5.91e-01s, cones: 3.01e+01s, accel: 4.49e-02s
# ------------------------------------------------------------------
# objective = -0.995189
# ------------------------------------------------------------------

# %% [markdown]
# # more tests

# %%
scs_sol_infid_no_warm = []
scs_sol_iter_no_warm = []
trans_infid_list = []

for gamma in np.linspace(0,0.1,11):
    ####################
    # set parameters for GKP
    ####################
    print('--- gamma =',gamma)
    Delta = 0.481   # 1/2 Delta^2 \approx photon number
    l_cut = 20      # number of Kraus operator taken into consideration
    m_sum_cutoff=20 # accuracy order of basis overlap
    M_sum_cutoff=5  # accuracy order of QEC matrix
    
    ####################
    # calculate QEC matrix for GKP
    ####################
    M_GKP = QECmat_GKP(Delta = Delta, gamma = gamma, l_cut = l_cut, m_sum_cutoff = m_sum_cutoff, M_sum_cutoff = M_sum_cutoff).orth_M()
    
    ####################
    # calculate optimal/near optimal recovery
    ####################
    GKP_QECprocess.QECmat = M_GKP  #update GKP QEC matrix
    GKP_QECprocess.update_SCSprob()
    
    # calculate transpose fidelity result directly
    trans_infid = GKP_QECprocess.transpose_infid_M()
    print('transpose infid direct:',trans_infid)

    # calculate transpose choi matrix, and test consistency
    trans_choi = GKP_QECprocess.transpose_choi()
    prob0 = GKP_QECprocess.SDP_set_prob()  # setup SDP problem
    prob0.variables()[0].save_value(trans_choi)# feed choi into the variable
    print('transpose infid by choi:',1-prob0.objective.value)
    

    # do SDP optimization
    sol = GKP_QECprocess.scs_solver.solve(warm_start = False)
                                          #x = GKP_QECprocess.transchoi_x, 
                                          #y = GKP_QECprocess.transchoi_y,
                                          #s = GKP_QECprocess.transchoi_s)
    print('infid by SDP:',1+sol['info']['pobj'],'iter:',sol['info']['iter'])
    scs_sol_infid_no_warm.append(1+sol['info']['pobj'])
    scs_sol_iter_no_warm.append(sol['info']['iter'])
    trans_infid_list.append(trans_infid)
# Out:
# --- gamma = 0.0
# transpose infid direct: 0.0
# transpose infid by choi: 1.1102230246251565e-16
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 1.31e+00  2.53e-01  7.79e+00 -6.71e-02  1.00e-01  9.29e-03
#    100| 3.87e-08  1.72e-08  8.28e-08 -1.00e+00  1.00e-01  5.49e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 5
    m_sum_cutoff=20 # accuracy order of basis overlap
    M_sum_cutoff=5  # accuracy order of QEC matrix
    
    ####################
    # calculate QEC matrix for GKP
    ####################
    M_GKP = QECmat_GKP(Delta = Delta, gamma = gamma, l_cut = l_cut, m_sum_cutoff = m_sum_cutoff, M_sum_cutoff = M_sum_cutoff).orth_M()
    
    ####################
    # calculate optimal/near optimal recovery
    ####################
    GKP_QECprocess.QECmat = M_GKP  #update GKP QEC matrix
    GKP_QECprocess.update_SCSprob()
    
    # calculate transpose fidelity result directly
    trans_infid = GKP_QECprocess.transpose_infid_M()
    print('transpose infid direct:',trans_infid)

    # calculate transpose choi matrix, and test consistency
    trans_choi = GKP_QECprocess.transpose_choi()
    prob0 = GKP_QECprocess.SDP_set_prob()  # setup SDP problem
    prob0.variables()[0].save_value(trans_choi)# feed choi into the variable
    print('transpose infid by choi:',1-prob0.objective.value)
    

    # do SDP optimization
    sol = GKP_QECprocess.scs_solver.solve(warm_start = True)
                                          #x = GKP_QECprocess.transchoi_x, 
                                          #y = GKP_QECprocess.transchoi_y,
                                          #s = GKP_QECprocess.transchoi_s)
    print('infid by SDP:',1+sol['info']['pobj'],'iter:',sol['info']['iter'])
    scs_sol_infid.append(1+sol['info']['pobj'])
    scs_sol_iter.append(sol['info']['iter'])
# Out:
# --- gamma = 0.0
# transpose infid direct: 0.0
# transpose infid by choi: 1.1102230246251565e-16
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.53e+00  3.28e-02  2.70e+00 -2.34e+00  2.01e-02  8.67e-03
#    125| 4.29e-08  3.45e-09  2.12e-12 -1.00e+00  7.58e-02  6.50e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.50e-01s = setup: 7.80e-05s + solve: 6.50e-01s
# 	 lin-sys: 1.13e-02s, cones: 6.31e-01s, accel: 8.16e-04s
# ------------------------------------------------------------------
# objective = -1.000000
# ------------------------------------------------------------------
# infid by SDP: 3.2341906930355435e-12 iter: 125
# --- gamma = 0.01
# transpose infid direct: 0.0007032768163517389
# transpose infid by choi: 0.0007032768163517389
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 7.25e-02  5.88e-03  8.87e-02 -9.56e-01  7.58e-02  9.15e-03
#    250| 3.57e-05  8.87e-05  4.21e-05 -9.99e-01  7.58e-02  1.34e+00
#    500| 2.84e-05  4.48e-05  3.35e-05 -9.99e-01  7.58e-02  2.67e+00
#    750| 1.98e-01  1.64e-02  1.20e-04 -9.99e-01  7.58e-02  3.98e+00
#   1000| 8.73e-07  1.56e-06  1.03e-06 -9.99e-01  7.58e-02  5.32e+00
#   1250| 8.80e-07  1.46e-06  1.04e-06 -9.99e-01  7.58e-02  6.77e+00
#   1500| 8.87e-07  1.46e-06  1.04e-06 -9.99e-01  7.58e-02  8.08e+00
#   1750| 4.15e-02  3.40e-03  1.23e-06 -9.99e-01  7.58e-02  9.47e+00
#   2000| 9.00e-07  1.46e-06  1.06e-06 -9.99e-01  7.58e-02  1.09e+01
#   2250| 9.06e-07  1.46e-06  1.07e-06 -9.99e-01  7.58e-02  1.22e+01
#   2500| 9.12e-07  1.46e-06  1.07e-06 -9.99e-01  7.58e-02  1.35e+01
+01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 3.00e+01s = setup: 1.21e-04s + solve: 3.00e+01s
# 	 lin-sys: 5.20e-01s, cones: 2.92e+01s, accel: 4.01e-02s
# ------------------------------------------------------------------
# objective = -0.993752
# ------------------------------------------------------------------
# infid by SDP: 0.006247122603004418 iter: 5725
# --- gamma = 0.07
# transpose infid direct: 0.008945546653718606
# transpose infid by choi: 0.008945546653718495
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 6.52e-02  3.19e-03  5.60e-02 -9.66e-01  7.58e-02  1.29e-02
#    250| 1.45e-06  2.07e-06  1.85e-06 -9.92e-01  7.58e-02  1.45e+00
#    500| 1.46e-06  2.07e-06  1.87e-06 -9.92e-01  7.58e-02  2.72e+00
#    625| 1.66e-07  2.79e-07  1.95e-07 -9.92e-01  7.58e-02  3.35e+00
# ------------------------------------------------------------------
# status:  solved
# timings: total: 3.35e+00s = setup: 9.03e-05s + solve: 3.35e+00s
# 	 lin-sys: 5.90e-02s, cones: 3.25e+00s, accel: 4.72e-03s
# ------------------------------------------------------------------
# objective = -0.992135
# ------------------------------------------------------------------
# infid by SDP: 0.007864659782058858 iter: 625
# --- gamma = 0.08
# transpose infid direct: 0.011093824705170174
# transpose infid by choi: 0.011093824705170396
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 6.42e-02  3.17e-03  5.36e-02 -9.65e-01  7.58e-02  1.12e-02
#    125| 4.66e-07  8.06e-07  3.85e-07 -9.90e-01  7.58e-02  6.89e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.89e-01s = setup: 7.89e-05s + solve: 6.89e-01s
# 	 lin-sys: 1.18e-02s, cones: 6.65e-01s, accel: 8.76e-04s
# ------------------------------------------------------------------
# objective = -0.990324
# ------------------------------------------------------------------
# infid by SDP: 0.009675689418174427 iter: 125
# --- gamma = 0.09
# transpose infid direct: 0.013491711403480489
# transpose infid by choi: 0.0134917114034806
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 6.32e-02  3.14e-03  5.14e-02 -9.65e-01  7.58e-02  1.48e-02
#    175| 5.29e-07  1.24e-06  6.92e-07 -9.88e-01  7.58e-02  1.01e+00
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.01e+00s = setup: 1.28e-04s + solve: 1.01e+00s
# 	 lin-sys: 1.74e-02s, cones: 9.77e-01s, accel: 1.33e-03s
# ------------------------------------------------------------------
# objective = -0.988311
# ------------------------------------------------------------------
# infid by SDP: 0.011688779113345316 iter: 175
# --- gamma = 0.1
# transpose infid direct: 0.0161492156999401
# transpose infid by choi: 0.0161492156999401
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 6.23e-02  3.12e-03  4.94e-02 -9.64e-01  7.58e-02  1.46e-02
#    250| 8.77e-07  1.50e-06  1.16e-06 -9.86e-01  7.58e-02  1.61e+00
#    500| 8.86e-07  1.49e-06  1.17e-06 -9.86e-01  7.58e-02  3.16e+00
#    750| 8.95e-07  1.49e-06  1.19e-06 -9.86e-01  7.58e-02  4.75e+00
#   1000| 9.03e-07  1.49e-06  1.20e-06 -9.86e-01  7.58e-02  6.29e+00
#   1250| 9.12e-07  1.50e-06  1.21e-06 -9.86e-01  7.58e-02  7.89e+00
#   1500| 9.20e-07  1.50e-06  1.22e-06 -9.86e-01  7.58e-02  9.51e+00
#   1750| 9.29e-07  1.50e-06  1.23e-06 -9.86e-01  7.58e-02  1.10e+01
plt.plot(np.linspace(0,0.1,11),scs_sol_iter,label="Warm start")
plt.plot(np.linspace(0,0.1,11),scs_sol_iter_no_warm,label="No warm start")
plt.ylabel("Iterations")
plt.xlabel(r"$\gamma$")
plt.legend()
plt.show()

# %%
scs_sol_infid1 = []
scs_sol_iter1 = []
sol_diff = []
all_sols = []
prev_sol = None

for gamma in np.linspace(0,0.1,101):
    ####################
    # set parameters for GKP
    ####################
    print('--- gamma =',gamma)
    Delta = 0.481   # 1/2 Delta^2 \approx photon number
    l_cut = 20      # number of Kraus operator taken into consideration
    m_sum_cutoff=20 # accuracy order of basis overlap
    M_sum_cutoff=5  # accuracy order of QEC matrix
    
    ####################
    # calculate QEC matrix for GKP
    ####################
    M_GKP = QECmat_GKP(Delta = Delta, gamma = gamma, l_cut = l_cut, m_sum_cutoff = m_sum_cutoff, M_sum_cutoff = M_sum_cutoff).orth_M()
    
    ####################
    # calculate optimal/near optimal recovery
    ####################
    GKP_QECprocess.QECmat = M_GKP  #update GKP QEC matrix
    GKP_QECprocess.update_SCSprob()
    
    # calculate transpose fidelity result directly
    trans_infid = GKP_QECprocess.transpose_infid_M()
    print('transpose infid direct:',trans_infid)

    # calculate transpose choi matrix, and test consistency
    trans_choi = GKP_QECprocess.transpose_choi()
    prob0 = GKP_QECprocess.SDP_set_prob()  # setup SDP problem
    prob0.variables()[0].save_value(trans_choi)# feed choi into the variable
    print('transpose infid by choi:',1-prob0.objective.value)
    

    # do SDP optimization
    if prev_sol == None:
        y_guess = GKP_QECprocess.transchoi_y
    else:
        y_guess = prev_sol['y']
        
    sol = GKP_QECprocess.scs_solver.solve(warm_start = True,
                                          x = GKP_QECprocess.transchoi_x, 
                                          y = y_guess,
                                          s = GKP_QECprocess.transchoi_s)
    print('infid by SDP:',1+sol['info']['pobj'],'iter:',sol['info']['iter'])
    scs_sol_infid1.append(1+sol['info']['pobj'])
    scs_sol_iter1.append(sol['info']['iter'])
    if prev_sol == None:
        prev_sol = sol
        continue
    sol_diff.append([np.linalg.norm(sol['x']-prev_sol['x']), np.linalg.norm(sol['y']-prev_sol['y'])])
    prev_sol = sol
    all_sols.append(sol)
# Out:
# --- gamma = 0.0
# transpose infid direct: 0.0
# transpose infid by choi: 1.1102230246251565e-16
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 1.10e+01  2.80e-01  4.26e-11 -1.00e+00  2.35e-02  8.03e-03
#     50| 6.52e-07  5.20e-08  7.79e-07 -1.00e+00  2.35e-02  2.45e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 2.45e-01s = setup: 1.07e-04s + solve: 2.45e-01s
# 	 lin-sys: 4.46e-03s, cones: 2.34e-01s, accel: 2.71e-04s
# ------------------------------------------------------------------
# objective = -0.999999
# ------------------------------------------------------------------
# infid by SDP: 9.79395501476965e-07 iter: 50
# --- gamma = 0.001
# transpose infid direct: 6.291763909471726e-05
# transpose infid by choi: 6.291763909460624e-05
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.36e-02  3.67e-04  2.59e-02 -9.87e-01  2.35e-02  1.34e-02
#    100| 5.80e-07  6.16e-08  6.19e-10 -1.00e+00  2.35e-02  5.20e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 5.20e-01s = setup: 9.66e-05s + solve: 5.20e-01s
# 	 lin-sys: 9.26e-03s, cones: 4.99e-01s, accel: 7.66e-04s
# ------------------------------------------------------------------
# objective = -0.999937
# ------------------------------------------------------------------
# infid by SDP: 6.273371785769921e-05 iter: 100
# --- gamma = 0.002
# transpose infid direct: 0.0001274491850791204
# transpose infid by choi: 0.0001274491850791204
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.36e-02  3.67e-04  2.57e-02 -9.87e-01  2.35e-02  2.43e-02
#    100| 5.77e-07  9.06e-08  5.03e-09 -1.00e+00  2.35e-02  5.12e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 5.12e-01s = setup: 1.01e-04s + solve: 5.12e-01s
# 	 lin-sys: 9.17e-03s, cones: 4.80e-01s, accel: 7.95e-04s
# ------------------------------------------------------------------
# objective = -0.999873
# ------------------------------------------------------------------
# infid by SDP: 0.0001266492050858714 iter: 100
# --- gamma = 0.003
# transpose infid direct: 0.000193607010627872
# transpose infid by choi: 0.000193607010627872
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.35e-02  3.66e-04  2.55e-02 -9.87e-01  2.35e-02  1.12e-02
#    100| 5.74e-07  7.63e-08  1.70e-08 -1.00e+00  2.35e-02  5.09e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 5.09e-01s = setup: 1.03e-04s + solve: 5.09e-01s
# 	 lin-sys: 9.15e-03s, cones: 4.88e-01s, accel: 8.42e-04s
# ------------------------------------------------------------------
# objective = -0.999808
# ------------------------------------------------------------------
# infid by SDP: 0.00019179985568107405 iter: 100
# --- gamma = 0.004
# transpose infid direct: 0.0002614034386012598
# transpose infid by choi: 0.0002614034386011488
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.35e-02  3.66e-04  2.54e-02 -9.87e-01  2.35e-02  1.62e-02
#    100| 5.71e-07  9.74e-08  4.01e-08 -1.00e+00  2.35e-02  5.10e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 5.10e-01s = setup: 1.09e-04s + solve: 5.10e-01s
# 	 lin-sys: 9.27e-03s, cones: 4.87e-01s, accel: 7.43e-04s
# ------------------------------------------------------------------
# objective = -0.999742
# ------------------------------------------------------------------
# infid by SDP: 0.00025820888287153565 iter: 100
# --- gamma = 0.005
# transpose infid direct: 0.0003308507434972574
# transpose infid by choi: 0.00033085074349703536
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.34e-02  3.65e-04  2.52e-02 -9.87e-01  2.35e-02  1.54e-02
#    100| 8.51e-07  1.89e-07  3.43e-08 -1.00e+00  2.35e-02  4.90e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 4.90e-01s = setup: 8.90e-05s + solve: 4.90e-01s
# 	 lin-sys: 9.44e-03s, cones: 4.68e-01s, accel: 7.01e-04s
# ------------------------------------------------------------------
# objective = -0.999674
# ------------------------------------------------------------------
# infid by SDP: 0.00032578646679448653 iter: 100
# --- gamma = 0.006
# transpose infid direct: 0.00040196115283852585
# transpose infid by choi: 0.00040196115283863687
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.34e-02  3.65e-04  2.51e-02 -9.87e-01  2.35e-02  1.09e-02
#    100| 5.81e-07  6.81e-08  1.34e-09 -1.00e+00  2.35e-02  4.77e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 4.77e-01s = setup: 9.19e-05s + solve: 4.77e-01s
# 	 lin-sys: 8.91e-03s, cones: 4.57e-01s, accel: 6.95e-04s
# ------------------------------------------------------------------
# objective = -0.999606
# ------------------------------------------------------------------
# infid by SDP: 0.0003943349976691657 iter: 100
# --- gamma = 0.007
# transpose infid direct: 0.00047474684855830507
# transpose infid by choi: 0.0004747468485584161
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.33e-02  3.64e-04  2.49e-02 -9.87e-01  2.35e-02  9.26e-03
#    100| 5.61e-07  1.05e-07  2.10e-09 -1.00e+00  2.35e-02  4.69e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 4.69e-01s = setup: 9.38e-05s + solve: 4.69e-01s
# 	 lin-sys: 8.84e-03s, cones: 4.50e-01s, accel: 6.68e-04s
# ------------------------------------------------------------------
# objective = -0.999536
# ------------------------------------------------------------------
# infid by SDP: 0.0004643833398810804 iter: 100
# --- gamma = 0.008
# transpose infid direct: 0.000549219968285608
# transpose infid by choi: 0.000549219968285386
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.33e-02  3.64e-04  2.48e-02 -9.87e-01  2.35e-02  1.33e-02
#    100| 5.58e-07  1.52e-07  3.59e-09 -9.99e-01  2.35e-02  4.96e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 4.96e-01s = setup: 8.92e-05s + solve: 4.96e-01s
# 	 lin-sys: 9.12e-03s, cones: 4.74e-01s, accel: 7.37e-04s
# ------------------------------------------------------------------
# objective = -0.999464
# ------------------------------------------------------------------
# infid by SDP: 0.0005356690402379405 iter: 100
# --- gamma = 0.009000000000000001
# transpose infid direct: 0.0006253926066227544
# transpose infid by choi: 0.0006253926066228654
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.33e-02  3.64e-04  2.46e-02 -9.87e-01  2.35e-02  1.04e-02
#    125| 2.97e-08  2.02e-07  5.67e-09 -9.99e-01  2.35e-02  5.85e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 5.85e-01s = setup: 9.75e-05s + solve: 5.85e-01s
# 	 lin-sys: 1.17e-02s, cones: 5.62e-01s, accel: 7.54e-04s
# ------------------------------------------------------------------
# objective = -0.999392
# ------------------------------------------------------------------
# infid by SDP: 0.000608209169794427 iter: 125
# --- gamma = 0.01
# transpose infid direct: 0.0007032768163517389
# transpose infid by choi: 0.0007032768163517389
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.32e-02  3.63e-04  2.45e-02 -9.87e-01  2.35e-02  1.71e-02
#    100| 5.52e-07  2.77e-07  8.63e-09 -9.99e-01  2.35e-02  4.87e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 4.87e-01s = setup: 8.78e-05s + solve: 4.87e-01s
# 	 lin-sys: 8.96e-03s, cones: 4.62e-01s, accel: 6.95e-04s
# ------------------------------------------------------------------
# objective = -0.999318
# ------------------------------------------------------------------
# infid by SDP: 0.0006820658236402766 iter: 100
# --- gamma = 0.011
# transpose infid direct: 0.0007828846096191722
# transpose infid by choi: 0.0007828846096189501
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.32e-02  3.63e-04  2.43e-02 -9.87e-01  2.35e-02  1.20e-02
#    125| 5.72e-08  3.36e-07  1.26e-08 -9.99e-01  2.35e-02  5.89e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 5.89e-01s = setup: 1.28e-04s + solve: 5.89e-01s
# 	 lin-sys: 1.16e-02s, cones: 5.65e-01s, accel: 8.80e-04s
# ------------------------------------------------------------------
# objective = -0.999243
# ------------------------------------------------------------------
# infid by SDP: 0.000757184451532722 iter: 125
# --- gamma = 0.012
# transpose infid direct: 0.0008642279590581614
# transpose infid by choi: 0.0008642279590579394
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.31e-02  3.62e-04  2.42e-02 -9.87e-01  2.35e-02  1.37e-02
#    100| 5.47e-07  4.41e-07  1.77e-08 -9.99e-01  2.35e-02  4.71e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 4.71e-01s = setup: 7.91e-05s + solve: 4.71e-01s
# 	 lin-sys: 9.13e-03s, cones: 4.49e-01s, accel: 6.49e-04s
# ------------------------------------------------------------------
# objective = -0.999166
# ------------------------------------------------------------------
# infid by SDP: 0.0008336437283953391 iter: 100
# --- gamma = 0.013000000000000001
# transpose infid direct: 0.0009473187988785492
# transpose infid by choi: 0.0009473187988786602
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.31e-02  3.62e-04  2.40e-02 -9.87e-01  2.35e-02  1.83e-02
#    125| 1.17e-07  4.97e-07  2.44e-08 -9.99e-01  2.35e-02  5.94e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 5.94e-01s = setup: 8.51e-05s + solve: 5.94e-01s
# 	 lin-sys: 1.20e-02s, cones: 5.66e-01s, accel: 7.51e-04s
# ------------------------------------------------------------------
# objective = -0.999089
# ------------------------------------------------------------------
# infid by SDP: 0.0009113868867849373 iter: 125
# --- gamma = 0.014
# transpose infid direct: 0.0010321690259024185
# transpose infid by choi: 0.0010321690259024185
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.30e-02  3.61e-04  2.39e-02 -9.87e-01  2.35e-02  2.40e-02
#    100| 5.42e-07  6.36e-07  3.26e-08 -9.99e-01  2.35e-02  5.22e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 5.22e-01s = setup: 9.38e-05s + solve: 5.22e-01s
# 	 lin-sys: 9.21e-03s, cones: 4.94e-01s, accel: 6.61e-04s
# ------------------------------------------------------------------
# objective = -0.999009
# ------------------------------------------------------------------
# infid by SDP: 0.0009904943092812202 iter: 100
# --- gamma = 0.015
# transpose infid direct: 0.0011187905005913823
# transpose infid by choi: 0.0011187905005911603
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.30e-02  3.61e-04  2.37e-02 -9.87e-01  2.35e-02  1.16e-02
#    125| 2.08e-07  6.73e-07  4.29e-08 -9.99e-01  2.35e-02  6.12e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.13e-01s = setup: 6.74e-05s + solve: 6.13e-01s
# 	 lin-sys: 1.29e-02s, cones: 5.89e-01s, accel: 8.10e-04s
# ------------------------------------------------------------------
# objective = -0.998929
# ------------------------------------------------------------------
# infid by SDP: 0.0010709112038124191 iter: 125
# --- gamma = 0.016
# transpose infid direct: 0.0012071950479658478
# transpose infid by choi: 0.0012071950479656257
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.29e-02  3.61e-04  2.36e-02 -9.87e-01  2.35e-02  1.36e-02
#    100| 5.38e-07  8.53e-07  5.52e-08 -9.99e-01  2.35e-02  4.90e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 4.90e-01s = setup: 9.04e-05s + solve: 4.90e-01s
# 	 lin-sys: 9.00e-03s, cones: 4.67e-01s, accel: 7.24e-04s
# ------------------------------------------------------------------
# objective = -0.998847
# ------------------------------------------------------------------
# infid by SDP: 0.0011527167910158065 iter: 100
# --- gamma = 0.017
# transpose infid direct: 0.0012973944585648045
# transpose infid by choi: 0.0012973944585648045
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.29e-02  3.60e-04  2.35e-02 -9.87e-01  2.35e-02  1.43e-02
#    125| 2.33e-06  8.53e-07  1.38e-08 -9.99e-01  2.35e-02  5.82e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 5.82e-01s = setup: 9.60e-05s + solve: 5.82e-01s
# 	 lin-sys: 1.14e-02s, cones: 5.56e-01s, accel: 8.01e-04s
# ------------------------------------------------------------------
# objective = -0.998764
# ------------------------------------------------------------------
# infid by SDP: 0.0012357541518341897 iter: 125
# --- gamma = 0.018000000000000002
# transpose infid direct: 0.0013894004893157952
# transpose infid by choi: 0.0013894004893157952
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.28e-02  3.60e-04  2.33e-02 -9.87e-01  2.35e-02  1.07e-02
#    100| 2.33e-06  1.08e-06  6.92e-08 -9.99e-01  2.35e-02  4.86e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 4.86e-01s = setup: 8.59e-05s + solve: 4.86e-01s
# 	 lin-sys: 9.17e-03s, cones: 4.67e-01s, accel: 7.39e-04s
# ------------------------------------------------------------------
# objective = -0.998680
# ------------------------------------------------------------------
# infid by SDP: 0.0013203322160418862 iter: 100
# --- gamma = 0.019
# transpose infid direct: 0.0014832248643611434
# transpose infid by choi: 0.0014832248643611434
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.28e-02  3.59e-04  2.32e-02 -9.87e-01  2.35e-02  2.66e-02
#    125| 4.93e-07  1.02e-06  4.29e-09 -9.99e-01  2.35e-02  6.30e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.30e-01s = setup: 9.39e-05s + solve: 6.30e-01s
# 	 lin-sys: 1.14e-02s, cones: 5.96e-01s, accel: 7.98e-04s
# ------------------------------------------------------------------
# objective = -0.998594
# ------------------------------------------------------------------
# infid by SDP: 0.0014059173034606243 iter: 125
# --- gamma = 0.02
# transpose infid direct: 0.0015788792758913983
# transpose infid by choi: 0.0015788792758911763
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.27e-02  3.59e-04  2.31e-02 -9.87e-01  2.35e-02  1.64e-02
#    100| 6.91e-07  1.30e-06  5.66e-09 -9.99e-01  2.35e-02  4.91e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 4.91e-01s = setup: 6.95e-05s + solve: 4.91e-01s
# 	 lin-sys: 9.01e-03s, cones: 4.68e-01s, accel: 9.53e-04s
# ------------------------------------------------------------------
# objective = -0.998507
# ------------------------------------------------------------------
# infid by SDP: 0.0014932218437163636 iter: 100
# --- gamma = 0.021
# transpose infid direct: 0.0016763753848990648
# transpose infid by choi: 0.0016763753848990648
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.27e-02  3.58e-04  2.29e-02 -9.87e-01  2.35e-02  1.13e-02
#    125| 6.82e-07  1.16e-06  7.02e-09 -9.98e-01  2.35e-02  6.11e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.11e-01s = setup: 6.96e-05s + solve: 6.11e-01s
# 	 lin-sys: 1.16e-02s, cones: 5.89e-01s, accel: 8.03e-04s
# ------------------------------------------------------------------
# objective = -0.998418
# ------------------------------------------------------------------
# infid by SDP: 0.0015817721941181473 iter: 125
# --- gamma = 0.022
# transpose infid direct: 0.0017757248219045785
# transpose infid by choi: 0.0017757248219043564
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.26e-02  3.63e-04  2.28e-02 -9.87e-01  2.35e-02  1.25e-02
#    125| 7.83e-07  1.23e-06  8.81e-09 -9.98e-01  2.35e-02  6.11e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.11e-01s = setup: 9.52e-05s + solve: 6.11e-01s
# 	 lin-sys: 1.16e-02s, cones: 5.84e-01s, accel: 8.31e-04s
# ------------------------------------------------------------------
# objective = -0.998328
# ------------------------------------------------------------------
# infid by SDP: 0.001671819935084251 iter: 125
# --- gamma = 0.023
# transpose infid direct: 0.001876939187664628
# transpose infid by choi: 0.001876939187664628
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.26e-02  3.80e-04  2.27e-02 -9.87e-01  2.35e-02  7.98e-03
#    125| 8.87e-07  1.28e-06  1.09e-08 -9.98e-01  2.35e-02  6.11e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.11e-01s = setup: 6.74e-05s + solve: 6.11e-01s
# 	 lin-sys: 1.21e-02s, cones: 5.89e-01s, accel: 8.19e-04s
# ------------------------------------------------------------------
# objective = -0.998237
# ------------------------------------------------------------------
# infid by SDP: 0.0017632934471933925 iter: 125
# --- gamma = 0.024
# transpose infid direct: 0.0019800300538286297
# transpose infid by choi: 0.0019800300538286297
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.25e-02  3.97e-04  2.26e-02 -9.87e-01  2.35e-02  1.33e-02
#    125| 9.93e-07  1.32e-06  1.34e-08 -9.98e-01  2.35e-02  6.10e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.10e-01s = setup: 1.69e-04s + solve: 6.10e-01s
# 	 lin-sys: 1.15e-02s, cones: 5.88e-01s, accel: 7.62e-04s
# ------------------------------------------------------------------
# objective = -0.998144
# ------------------------------------------------------------------
# infid by SDP: 0.0018562015066170279 iter: 125
# --- gamma = 0.025
# transpose infid direct: 0.0020850089635620073
# transpose infid by choi: 0.0020850089635618962
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.25e-02  4.14e-04  2.25e-02 -9.87e-01  2.35e-02  1.05e-02
#    150| 8.48e-07  1.05e-06  1.63e-08 -9.98e-01  2.35e-02  7.20e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 7.20e-01s = setup: 7.82e-05s + solve: 7.20e-01s
# 	 lin-sys: 1.34e-02s, cones: 6.94e-01s, accel: 1.11e-03s
# ------------------------------------------------------------------
# objective = -0.998049
# ------------------------------------------------------------------
# infid by SDP: 0.0019505428040822448 iter: 150
# --- gamma = 0.026000000000000002
# transpose infid direct: 0.0021918874321498194
# transpose infid by choi: 0.0021918874321498194
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.24e-02  4.31e-04  2.23e-02 -9.87e-01  2.35e-02  1.33e-02
#    175| 2.45e-07  4.43e-08  2.01e-08 -9.98e-01  2.35e-02  8.42e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 8.42e-01s = setup: 9.60e-05s + solve: 8.42e-01s
# 	 lin-sys: 1.61e-02s, cones: 8.10e-01s, accel: 1.85e-03s
# ------------------------------------------------------------------
# objective = -0.997954
# ------------------------------------------------------------------
# infid by SDP: 0.002046300967468717 iter: 175
# --- gamma = 0.027
# transpose infid direct: 0.002300676947542546
# transpose infid by choi: 0.002300676947542657
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.24e-02  4.48e-04  2.22e-02 -9.87e-01  2.35e-02  1.38e-02
#    150| 9.67e-07  1.03e-06  2.36e-08 -9.98e-01  2.35e-02  7.11e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 7.11e-01s = setup: 7.38e-05s + solve: 7.11e-01s
# 	 lin-sys: 1.39e-02s, cones: 6.83e-01s, accel: 1.01e-03s
# ------------------------------------------------------------------
# objective = -0.997856
# ------------------------------------------------------------------
# infid by SDP: 0.002143631601741025 iter: 150
# --- gamma = 0.028
# transpose infid direct: 0.002411388970901873
# transpose infid by choi: 0.002411388970901651
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.23e-02  4.65e-04  2.21e-02 -9.87e-01  2.35e-02  9.60e-03
#    200| 2.07e-07  6.28e-08  2.82e-08 -9.98e-01  2.35e-02  9.44e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 9.44e-01s = setup: 1.76e-04s + solve: 9.44e-01s
# 	 lin-sys: 1.82e-02s, cones: 9.11e-01s, accel: 1.98e-03s
# ------------------------------------------------------------------
# objective = -0.997758
# ------------------------------------------------------------------
# infid by SDP: 0.0022424078114665624 iter: 200
# --- gamma = 0.029
# transpose infid direct: 0.0025240349370896364
# transpose infid by choi: 0.0025240349370894144
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.23e-02  4.83e-04  2.20e-02 -9.87e-01  2.35e-02  1.89e-02
#    150| 1.06e-06  9.89e-07  3.34e-08 -9.98e-01  2.35e-02  7.16e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 7.16e-01s = setup: 9.28e-05s + solve: 7.16e-01s
# 	 lin-sys: 1.38e-02s, cones: 6.80e-01s, accel: 9.23e-04s
# ------------------------------------------------------------------
# objective = -0.997657
# ------------------------------------------------------------------
# infid by SDP: 0.0023426369312683493 iter: 150
# --- gamma = 0.03
# transpose infid direct: 0.002638626255126564
# transpose infid by choi: 0.0026386262551262307
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.23e-02  5.00e-04  2.19e-02 -9.87e-01  2.35e-02  1.29e-02
#    150| 1.10e-06  9.71e-07  3.93e-08 -9.98e-01  2.35e-02  7.27e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 7.27e-01s = setup: 1.79e-04s + solve: 7.27e-01s
# 	 lin-sys: 1.37e-02s, cones: 7.00e-01s, accel: 1.23e-03s
# ------------------------------------------------------------------
# objective = -0.997556
# ------------------------------------------------------------------
# infid by SDP: 0.0024443864395528037 iter: 150
# --- gamma = 0.031
# transpose infid direct: 0.002755174308647357
# transpose infid by choi: 0.002755174308647357
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.22e-02  5.17e-04  2.18e-02 -9.87e-01  2.35e-02  8.63e-03
#    150| 1.11e-06  9.20e-07  4.59e-08 -9.97e-01  2.35e-02  7.23e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 7.23e-01s = setup: 8.78e-05s + solve: 7.23e-01s
# 	 lin-sys: 1.36e-02s, cones: 6.98e-01s, accel: 9.00e-04s
# ------------------------------------------------------------------
# objective = -0.997452
# ------------------------------------------------------------------
# infid by SDP: 0.0025476475461670978 iter: 150
# --- gamma = 0.032
# transpose infid direct: 0.002873690456291045
# transpose infid by choi: 0.002873690456291156
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.22e-02  5.34e-04  2.17e-02 -9.87e-01  2.35e-02  1.24e-02
#    125| 1.68e-06  1.32e-06  5.35e-08 -9.97e-01  2.35e-02  5.99e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 5.99e-01s = setup: 9.05e-05s + solve: 5.99e-01s
# 	 lin-sys: 1.12e-02s, cones: 5.77e-01s, accel: 7.36e-04s
# ------------------------------------------------------------------
# objective = -0.997348
# ------------------------------------------------------------------
# infid by SDP: 0.002652443449583264 iter: 125
# --- gamma = 0.033
# transpose infid direct: 0.00299418603208379
# transpose infid by choi: 0.00299418603208379
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.24e-02  5.51e-04  2.16e-02 -9.87e-01  2.35e-02  1.21e-02
#    125| 1.73e-06  1.28e-06  4.46e-08 -9.97e-01  2.35e-02  6.19e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.19e-01s = setup: 9.56e-05s + solve: 6.19e-01s
# 	 lin-sys: 1.12e-02s, cones: 5.95e-01s, accel: 8.13e-04s
# ------------------------------------------------------------------
# objective = -0.997241
# ------------------------------------------------------------------
# infid by SDP: 0.0027586734621426467 iter: 125
# --- gamma = 0.034
# transpose infid direct: 0.0031166723458055934
# transpose infid by choi: 0.0031166723458057044
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.31e-02  5.68e-04  2.14e-02 -9.87e-01  2.35e-02  7.99e-03
#    125| 1.77e-06  1.24e-06  4.44e-08 -9.97e-01  2.35e-02  6.04e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.05e-01s = setup: 9.43e-05s + solve: 6.04e-01s
# 	 lin-sys: 1.13e-02s, cones: 5.83e-01s, accel: 9.15e-04s
# ------------------------------------------------------------------
# objective = -0.997134
# ------------------------------------------------------------------
# infid by SDP: 0.002866430226945438 iter: 125
# --- gamma = 0.035
# transpose infid direct: 0.003241160683293165
# transpose infid by choi: 0.003241160683293276
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.38e-02  5.85e-04  2.13e-02 -9.86e-01  2.35e-02  1.22e-02
#    125| 1.79e-06  1.19e-06  4.12e-08 -9.97e-01  2.35e-02  6.07e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.07e-01s = setup: 6.74e-05s + solve: 6.07e-01s
# 	 lin-sys: 1.15e-02s, cones: 5.82e-01s, accel: 7.73e-04s
# ------------------------------------------------------------------
# objective = -0.997024
# ------------------------------------------------------------------
# infid by SDP: 0.0029758961507444504 iter: 125
# --- gamma = 0.036000000000000004
# transpose infid direct: 0.0033676623067381284
# transpose infid by choi: 0.0033676623067381284
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.44e-02  6.02e-04  2.12e-02 -9.86e-01  2.35e-02  1.98e-02
#    125| 1.81e-06  1.14e-06  3.37e-09 -9.97e-01  2.35e-02  6.14e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.14e-01s = setup: 9.59e-05s + solve: 6.14e-01s
# 	 lin-sys: 1.12e-02s, cones: 5.88e-01s, accel: 7.80e-04s
# ------------------------------------------------------------------
# objective = -0.996913
# ------------------------------------------------------------------
# infid by SDP: 0.0030867523643067774 iter: 125
# --- gamma = 0.037
# transpose infid direct: 0.003496188454972571
# transpose infid by choi: 0.003496188454972571
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.51e-02  6.19e-04  2.11e-02 -9.86e-01  2.35e-02  1.42e-02
#    150| 1.03e-06  2.30e-07  1.08e-07 -9.97e-01  2.35e-02  7.35e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 7.36e-01s = setup: 6.76e-05s + solve: 7.35e-01s
# 	 lin-sys: 1.37e-02s, cones: 7.06e-01s, accel: 1.55e-03s
# ------------------------------------------------------------------
# objective = -0.996801
# ------------------------------------------------------------------
# infid by SDP: 0.0031991350437853283 iter: 150
# --- gamma = 0.038
# transpose infid direct: 0.003626750343703744
# transpose infid by choi: 0.003626750343703744
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.58e-02  6.36e-04  2.10e-02 -9.86e-01  2.35e-02  1.92e-02
#    125| 1.80e-06  1.04e-06  5.44e-09 -9.97e-01  2.35e-02  6.22e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.22e-01s = setup: 1.36e-04s + solve: 6.22e-01s
# 	 lin-sys: 1.17e-02s, cones: 5.93e-01s, accel: 8.30e-04s
# ------------------------------------------------------------------
# objective = -0.996687
# ------------------------------------------------------------------
# infid by SDP: 0.0033133381802727957 iter: 125
# --- gamma = 0.039
# transpose infid direct: 0.0037593591657378855
# transpose infid by choi: 0.0037593591657378855
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.65e-02  6.53e-04  2.09e-02 -9.86e-01  2.35e-02  1.72e-02
#    125| 1.78e-06  9.77e-07  6.27e-09 -9.97e-01  2.35e-02  6.61e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.61e-01s = setup: 9.31e-05s + solve: 6.61e-01s
# 	 lin-sys: 1.25e-02s, cones: 6.33e-01s, accel: 8.17e-04s
# ------------------------------------------------------------------
# objective = -0.996571
# ------------------------------------------------------------------
# infid by SDP: 0.003429038577029142 iter: 125
# --- gamma = 0.04
# transpose infid direct: 0.0038940260911700664
# transpose infid by choi: 0.0038940260911701774
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.72e-02  6.70e-04  2.09e-02 -9.86e-01  2.35e-02  1.20e-02
#    125| 1.75e-06  9.19e-07  7.28e-09 -9.96e-01  2.35e-02  6.05e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.05e-01s = setup: 9.26e-05s + solve: 6.05e-01s
# 	 lin-sys: 1.21e-02s, cones: 5.80e-01s, accel: 7.77e-04s
# ------------------------------------------------------------------
# objective = -0.996454
# ------------------------------------------------------------------
# infid by SDP: 0.0035463488846385616 iter: 125
# --- gamma = 0.041
# transpose infid direct: 0.004030762267567156
# transpose infid by choi: 0.004030762267567156
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.79e-02  6.87e-04  2.08e-02 -9.86e-01  2.35e-02  2.83e-02
#    125| 1.71e-06  8.61e-07  8.33e-09 -9.96e-01  2.35e-02  5.99e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 5.99e-01s = setup: 9.61e-05s + solve: 5.99e-01s
# 	 lin-sys: 1.17e-02s, cones: 5.62e-01s, accel: 7.85e-04s
# ------------------------------------------------------------------
# objective = -0.996335
# ------------------------------------------------------------------
# infid by SDP: 0.003665277134233591 iter: 125
# --- gamma = 0.042
# transpose infid direct: 0.0041695788201095985
# transpose infid by choi: 0.004169578820109376
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.86e-02  7.04e-04  2.07e-02 -9.86e-01  2.35e-02  9.21e-03
#    125| 1.67e-06  8.03e-07  9.52e-09 -9.96e-01  2.35e-02  6.04e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.04e-01s = setup: 1.89e-04s + solve: 6.04e-01s
# 	 lin-sys: 1.12e-02s, cones: 5.83e-01s, accel: 7.70e-04s
# ------------------------------------------------------------------
# objective = -0.996214
# ------------------------------------------------------------------
# infid by SDP: 0.0037858333603847383 iter: 125
# --- gamma = 0.043000000000000003
# transpose infid direct: 0.004310486851727413
# transpose infid by choi: 0.004310486851727413
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.93e-02  7.21e-04  2.06e-02 -9.86e-01  2.35e-02  1.72e-02
#    125| 1.62e-06  7.47e-07  1.09e-08 -9.96e-01  2.35e-02  6.63e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.63e-01s = setup: 9.23e-05s + solve: 6.63e-01s
# 	 lin-sys: 1.14e-02s, cones: 6.35e-01s, accel: 8.04e-04s
# ------------------------------------------------------------------
# objective = -0.996092
# ------------------------------------------------------------------
# infid by SDP: 0.003908027328589081 iter: 125
# --- gamma = 0.044
# transpose infid direct: 0.004453497443192012
# transpose infid by choi: 0.004453497443192123
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.99e-02  7.38e-04  2.05e-02 -9.86e-01  2.35e-02  1.47e-02
#    125| 1.56e-06  6.91e-07  1.24e-08 -9.96e-01  2.35e-02  6.87e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.87e-01s = setup: 7.44e-05s + solve: 6.87e-01s
# 	 lin-sys: 1.29e-02s, cones: 6.58e-01s, accel: 8.28e-04s
# ------------------------------------------------------------------
# objective = -0.995968
# ------------------------------------------------------------------
# infid by SDP: 0.0040318706259174775 iter: 125
# --- gamma = 0.045
# transpose infid direct: 0.004598621653218893
# transpose infid by choi: 0.00459862165321856
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 3.06e-02  7.55e-04  2.04e-02 -9.86e-01  2.35e-02  1.18e-02
#    125| 1.49e-06  6.38e-07  1.40e-08 -9.96e-01  2.35e-02  6.02e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.02e-01s = setup: 9.23e-05s + solve: 6.02e-01s
# 	 lin-sys: 1.14e-02s, cones: 5.78e-01s, accel: 7.66e-04s
# ------------------------------------------------------------------
# objective = -0.995843
# ------------------------------------------------------------------
# infid by SDP: 0.004157373958437294 iter: 125
# --- gamma = 0.046
# transpose infid direct: 0.004745870518509943
# transpose infid by choi: 0.004745870518509943
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 3.13e-02  7.72e-04  2.03e-02 -9.86e-01  2.35e-02  1.45e-02
#    125| 1.47e-06  6.05e-07  1.58e-08 -9.96e-01  2.35e-02  6.04e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.04e-01s = setup: 9.08e-05s + solve: 6.04e-01s
# 	 lin-sys: 1.14e-02s, cones: 5.77e-01s, accel: 1.25e-03s
# ------------------------------------------------------------------
# objective = -0.995715
# ------------------------------------------------------------------
# infid by SDP: 0.004284546567448477 iter: 125
# --- gamma = 0.047
# transpose infid direct: 0.004895255053819492
# transpose infid by choi: 0.004895255053819492
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 3.20e-02  7.89e-04  2.02e-02 -9.86e-01  2.35e-02  1.70e-02
#    125| 1.36e-06  5.38e-07  1.78e-08 -9.96e-01  2.35e-02  6.11e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.11e-01s = setup: 9.18e-05s + solve: 6.11e-01s
# 	 lin-sys: 1.16e-02s, cones: 5.83e-01s, accel: 7.90e-04s
# ------------------------------------------------------------------
# objective = -0.995587
# ------------------------------------------------------------------
# infid by SDP: 0.004413401652463289 iter: 125
# --- gamma = 0.048
# transpose infid direct: 0.0050467862519611995
# transpose infid by choi: 0.005046786251961088
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 3.27e-02  8.06e-04  2.01e-02 -9.86e-01  2.35e-02  1.29e-02
#    125| 1.29e-06  4.91e-07  2.00e-08 -9.95e-01  2.35e-02  6.28e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.28e-01s = setup: 8.89e-05s + solve: 6.28e-01s
# 	 lin-sys: 1.19e-02s, cones: 6.03e-01s, accel: 8.56e-04s
# ------------------------------------------------------------------
# objective = -0.995456
# ------------------------------------------------------------------
# infid by SDP: 0.004543947302467877 iter: 125
# --- gamma = 0.049
# transpose infid direct: 0.00520047508381527
# transpose infid by choi: 0.00520047508381527
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 3.34e-02  8.23e-04  2.01e-02 -9.85e-01  2.35e-02  1.05e-02
#    125| 1.21e-06  4.47e-07  2.24e-08 -9.95e-01  2.35e-02  6.00e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.00e-01s = setup: 9.17e-05s + solve: 6.00e-01s
# 	 lin-sys: 1.17e-02s, cones: 5.78e-01s, accel: 8.08e-04s
# ------------------------------------------------------------------
# objective = -0.995324
# ------------------------------------------------------------------
# infid by SDP: 0.004676194691357827 iter: 125
# --- gamma = 0.05
# transpose infid direct: 0.005356332498326899
# transpose infid by choi: 0.00535633249832701
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 3.41e-02  8.39e-04  2.00e-02 -9.85e-01  2.35e-02  1.22e-02
#    125| 1.14e-06  4.06e-07  2.51e-08 -9.95e-01  2.35e-02  6.17e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.17e-01s = setup: 1.79e-04s + solve: 6.17e-01s
# 	 lin-sys: 1.15e-02s, cones: 5.93e-01s, accel: 7.86e-04s
# ------------------------------------------------------------------
# objective = -0.995190
# ------------------------------------------------------------------
# infid by SDP: 0.004810154497231212 iter: 125
# --- gamma = 0.051000000000000004
# transpose infid direct: 0.0055143694224584205
# transpose infid by choi: 0.0055143694224583095
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 3.48e-02  8.56e-04  1.99e-02 -9.85e-01  2.35e-02  1.34e-02
#    125| 1.07e-06  3.68e-07  2.80e-08 -9.95e-01  2.35e-02  6.31e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.32e-01s = setup: 8.53e-05s + solve: 6.31e-01s
# 	 lin-sys: 1.13e-02s, cones: 6.05e-01s, accel: 8.21e-04s
# ------------------------------------------------------------------
# objective = -0.995054
# ------------------------------------------------------------------
# infid by SDP: 0.004945837038697665 iter: 125
# --- gamma = 0.052000000000000005
# transpose infid direct: 0.0056745967611522286
# transpose infid by choi: 0.005674596761152451
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 3.54e-02  8.73e-04  1.98e-02 -9.85e-01  2.35e-02  8.36e-03
#    125| 9.97e-07  3.83e-07  3.11e-08 -9.95e-01  2.35e-02  6.24e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.24e-01s = setup: 9.71e-05s + solve: 6.24e-01s
# 	 lin-sys: 1.11e-02s, cones: 6.03e-01s, accel: 7.68e-04s
# ------------------------------------------------------------------
# objective = -0.994917
# ------------------------------------------------------------------
# infid by SDP: 0.005083252729271015 iter: 125
# --- gamma = 0.053
# transpose infid direct: 0.005837025397255613
# transpose infid by choi: 0.005837025397255946
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 3.61e-02  8.90e-04  1.98e-02 -9.85e-01  2.35e-02  2.44e-02
#    125| 9.27e-07  4.10e-07  3.45e-08 -9.95e-01  2.35e-02  6.51e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 6.51e-01s = setup: 8.91e-05s + solve: 6.51e-01s
# 	 lin-sys: 1.17e-02s, cones: 6.17e-01s, accel: 7.82e-04s
# ------------------------------------------------------------------
# objective = -0.994778
# ------------------------------------------------------------------
# infid by SDP: 0.005222411934405091 iter: 125
# --- gamma = 0.054
# transpose infid direct: 0.006001666191448596
# transpose infid by choi: 0.006001666191448596
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 3.68e-02  9.07e-04  1.97e-02 -9.85e-01  2.35e-02  1.09e-02
#    100| 2.38e-06  7.46e-07  3.84e-08 -9.95e-01  2.35e-02  5.15e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 5.15e-01s = setup: 9.34e-05s + solve: 5.15e-01s
# 	 lin-sys: 9.13e-03s, cones: 4.94e-01s, accel: 7.21e-04s
# ------------------------------------------------------------------
# objective = -0.994637
# ------------------------------------------------------------------
# infid by SDP: 0.0053633378223699735 iter: 100
# --- gamma = 0.055
# transpose infid direct: 0.006168529982126247
# transpose infid by choi: 0.0061685299821265804
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 3.75e-02  9.24e-04  1.96e-02 -9.85e-01  2.35e-02  9.13e-03
#    100| 2.27e-06  6.90e-07  4.24e-08 -9.94e-01  2.35e-02  5.09e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 5.09e-01s = setup: 1.83e-04s + solve: 5.09e-01s
# 	 lin-sys: 8.98e-03s, cones: 4.90e-01s, accel: 7.29e-04s
# ------------------------------------------------------------------
# objective = -0.994494
# ------------------------------------------------------------------
# infid by SDP: 0.0055060150655795725 iter: 100
# --- gamma = 0.056
# transpose infid direct: 0.0063376275853052055
# transpose infid by choi: 0.0063376275853049835
# ...
# infid by SDP: 0.010061109100367505 iter: 175
# --- gamma = 0.083
# transpose infid direct: 0.01178652031476346
# transpose infid by choi: 0.01178652031476346
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 5.65e-02  1.40e-03  1.81e-02 -9.81e-01  2.35e-02  1.26e-02
#    150| 7.69e-07  1.16e-06  4.11e-08 -9.90e-01  2.35e-02  7.76e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 7.76e-01s = setup: 8.03e-05s + solve: 7.76e-01s
# 	 lin-sys: 1.37e-02s, cones: 7.47e-01s, accel: 9.05e-04s
# ------------------------------------------------------------------
# objective = -0.989743
# ------------------------------------------------------------------
# infid by SDP: 0.010257211377915021 iter: 150
# --- gamma = 0.084
# transpose infid direct: 0.012022458778609635
# transpose infid by choi: 0.012022458778609746
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 5.71e-02  1.41e-03  1.81e-02 -9.81e-01  2.35e-02  1.49e-02
#    150| 8.02e-07  1.18e-06  4.41e-08 -9.90e-01  2.35e-02  7.76e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 7.76e-01s = setup: 9.12e-05s + solve: 7.76e-01s
# 	 lin-sys: 1.41e-02s, cones: 7.45e-01s, accel: 9.16e-04s
# ------------------------------------------------------------------
# objective = -0.989545
# ------------------------------------------------------------------
# infid by SDP: 0.01045534762321021 iter: 150
# --- gamma = 0.085
# transpose infid direct: 0.012260934000099089
# transpose infid by choi: 0.012260934000099089
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 5.78e-02  1.43e-03  1.80e-02 -9.81e-01  2.35e-02  1.36e-02
#    150| 8.42e-07  1.20e-06  4.74e-08 -9.89e-01  2.35e-02  7.78e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 7.78e-01s = setup: 8.80e-05s + solve: 7.78e-01s
# 	 lin-sys: 1.38e-02s, cones: 7.48e-01s, accel: 1.26e-03s
# ------------------------------------------------------------------
# objective = -0.989344
# ------------------------------------------------------------------
# infid by SDP: 0.010655541348169706 iter: 150
# --- gamma = 0.08600000000000001
# transpose infid direct: 0.012501956009112747
# transpose infid by choi: 0.012501956009112636
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 5.85e-02  1.45e-03  1.80e-02 -9.80e-01  2.35e-02  1.39e-02
#    150| 8.67e-07  1.21e-06  3.11e-08 -9.89e-01  2.35e-02  7.72e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 7.72e-01s = setup: 8.79e-05s + solve: 7.72e-01s
# 	 lin-sys: 1.35e-02s, cones: 7.43e-01s, accel: 9.26e-04s
# ------------------------------------------------------------------
# objective = -0.989142
# ------------------------------------------------------------------
# infid by SDP: 0.010857798561648035 iter: 150
# --- gamma = 0.08700000000000001
# transpose infid direct: 0.012745534803939806
# transpose infid by choi: 0.012745534803939806
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 5.92e-02  1.46e-03  1.80e-02 -9.80e-01  2.35e-02  1.78e-02
#    175| 7.14e-07  1.22e-06  4.42e-08 -9.89e-01  2.35e-02  9.13e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 9.13e-01s = setup: 1.81e-04s + solve: 9.13e-01s
# 	 lin-sys: 1.62e-02s, cones: 8.78e-01s, accel: 1.28e-03s
# ------------------------------------------------------------------
# objective = -0.988938
# ------------------------------------------------------------------
# infid by SDP: 0.011062082951248331 iter: 175
# --- gamma = 0.088
# transpose infid direct: 0.012991680350863621
# transpose infid by choi: 0.012991680350863621
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 5.98e-02  1.48e-03  1.79e-02 -9.80e-01  2.35e-02  1.61e-02
#    150| 9.32e-07  1.30e-06  4.80e-08 -9.89e-01  2.35e-02  7.90e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 7.90e-01s = setup: 7.89e-05s + solve: 7.90e-01s
# 	 lin-sys: 1.37e-02s, cones: 7.62e-01s, accel: 8.96e-04s
# ------------------------------------------------------------------
# objective = -0.988731
# ------------------------------------------------------------------
# infid by SDP: 0.011268514409938257 iter: 150
# --- gamma = 0.089
# transpose infid direct: 0.013240402583726829
# transpose infid by choi: 0.013240402583726829
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 6.05e-02  1.50e-03  1.79e-02 -9.80e-01  2.35e-02  2.16e-02
#    200| 5.86e-07  1.28e-06  3.22e-08 -9.89e-01  2.35e-02  1.04e+00
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.04e+00s = setup: 1.21e-04s + solve: 1.04e+00s
# 	 lin-sys: 1.80e-02s, cones: 1.01e+00s, accel: 1.41e-03s
# ------------------------------------------------------------------
# objective = -0.988523
# ------------------------------------------------------------------
# infid by SDP: 0.01147693168154762 iter: 200
# --- gamma = 0.09
# transpose infid direct: 0.013491711403480489
# transpose infid by choi: 0.0134917114034806
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 6.12e-02  1.51e-03  1.79e-02 -9.80e-01  2.35e-02  1.60e-02
#    225| 4.60e-07  1.28e-06  9.73e-09 -9.88e-01  2.35e-02  1.17e+00
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.17e+00s = setup: 9.39e-05s + solve: 1.17e+00s
# 	 lin-sys: 2.03e-02s, cones: 1.13e+00s, accel: 1.48e-03s
# ------------------------------------------------------------------
# objective = -0.988313
# ------------------------------------------------------------------
# infid by SDP: 0.011687450763526841 iter: 225
# --- gamma = 0.091
# transpose infid direct: 0.01374561667779517
# transpose infid by choi: 0.013745616677795058
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 6.18e-02  1.53e-03  1.78e-02 -9.79e-01  2.35e-02  1.37e-02
#    250| 3.56e-07  1.29e-06  1.04e-08 -9.88e-01  2.35e-02  1.26e+00
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.26e+00s = setup: 9.59e-05s + solve: 1.26e+00s
# 	 lin-sys: 2.24e-02s, cones: 1.22e+00s, accel: 1.59e-03s
# ------------------------------------------------------------------
# objective = -0.988100
# ------------------------------------------------------------------
# infid by SDP: 0.011900143197729252 iter: 250
# --- gamma = 0.092
# transpose infid direct: 0.014002128240562906
# transpose infid by choi: 0.014002128240562906
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 6.25e-02  1.55e-03  1.78e-02 -9.79e-01  2.35e-02  1.31e-02
#    250| 3.57e-07  1.33e-06  1.12e-08 -9.88e-01  2.35e-02  1.31e+00
#    275| 2.75e-07  1.29e-06  1.12e-08 -9.88e-01  2.35e-02  1.44e+00
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.44e+00s = setup: 9.00e-05s + solve: 1.44e+00s
# 	 lin-sys: 2.54e-02s, cones: 1.39e+00s, accel: 2.57e-03s
# ------------------------------------------------------------------
# objective = -0.987885
# ------------------------------------------------------------------
# infid by SDP: 0.012114960894006543 iter: 275
# --- gamma = 0.093
# transpose infid direct: 0.01426125589148941
# transpose infid by choi: 0.014261255891489077
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 6.32e-02  1.56e-03  1.78e-02 -9.79e-01  2.35e-02  1.60e-02
#    250| 3.58e-07  1.37e-06  1.20e-08 -9.88e-01  2.35e-02  1.29e+00
#    300| 2.04e-07  1.28e-06  1.21e-08 -9.88e-01  2.35e-02  1.55e+00
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.55e+00s = setup: 1.11e-04s + solve: 1.55e+00s
# 	 lin-sys: 2.71e-02s, cones: 1.50e+00s, accel: 1.78e-03s
# ------------------------------------------------------------------
# objective = -0.987668
# ------------------------------------------------------------------
# infid by SDP: 0.012331905417616085 iter: 300
# --- gamma = 0.094
# transpose infid direct: 0.014523009395630337
# transpose infid by choi: 0.014523009395630115
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 6.38e-02  1.58e-03  1.78e-02 -9.79e-01  2.35e-02  1.04e-02
#    250| 1.75e-04  4.32e-06  1.49e-05 -9.87e-01  2.35e-02  1.29e+00
#    300| 7.25e-07  2.24e-07  8.70e-08 -9.87e-01  2.35e-02  1.55e+00
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.55e+00s = setup: 9.53e-05s + solve: 1.55e+00s
# 	 lin-sys: 2.68e-02s, cones: 1.50e+00s, accel: 2.84e-03s
# ------------------------------------------------------------------
# objective = -0.987449
# ------------------------------------------------------------------
# infid by SDP: 0.012551119975070413 iter: 300
# --- gamma = 0.095
# transpose infid direct: 0.014787398482934533
# transpose infid by choi: 0.01478739848293431
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 6.45e-02  1.60e-03  1.77e-02 -9.79e-01  2.35e-02  1.25e-02
#    250| 3.57e-07  1.46e-06  1.38e-08 -9.87e-01  2.35e-02  1.33e+00
#    350| 5.94e-07  2.21e-07  1.42e-08 -9.87e-01  2.35e-02  1.85e+00
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.85e+00s = setup: 6.86e-05s + solve: 1.85e+00s
# 	 lin-sys: 3.19e-02s, cones: 1.80e+00s, accel: 2.69e-03s
# ------------------------------------------------------------------
# objective = -0.987228
# ------------------------------------------------------------------
# infid by SDP: 0.01277214715941255 iter: 350
# --- gamma = 0.096
# transpose infid direct: 0.015054432847790622
# transpose infid by choi: 0.015054432847790955
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 6.52e-02  1.61e-03  1.77e-02 -9.78e-01  2.35e-02  1.25e-02
#    250| 3.55e-07  1.50e-06  1.48e-08 -9.87e-01  2.35e-02  1.29e+00
#    325| 9.63e-07  2.33e-07  1.51e-08 -9.87e-01  2.35e-02  1.69e+00
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.69e+00s = setup: 6.71e-05s + solve: 1.69e+00s
# 	 lin-sys: 2.93e-02s, cones: 1.63e+00s, accel: 2.52e-03s
# ------------------------------------------------------------------
# objective = -0.987004
# ------------------------------------------------------------------
# infid by SDP: 0.01299595732005343 iter: 325
# --- gamma = 0.097
# transpose infid direct: 0.015324122148564934
# transpose infid by choi: 0.015324122148565156
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 6.58e-02  1.63e-03  1.77e-02 -9.78e-01  2.35e-02  9.90e-03
#    250| 3.53e-07  1.54e-06  1.59e-08 -9.87e-01  2.35e-02  1.28e+00
#    350| 1.27e-06  2.37e-07  1.63e-08 -9.87e-01  2.35e-02  1.80e+00
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.81e+00s = setup: 9.48e-05s + solve: 1.80e+00s
# 	 lin-sys: 3.18e-02s, cones: 1.75e+00s, accel: 2.60e-03s
# ------------------------------------------------------------------
# objective = -0.986779
# ------------------------------------------------------------------
# infid by SDP: 0.013220778499376085 iter: 350
# --- gamma = 0.098
# transpose infid direct: 0.015596476007138649
# transpose infid by choi: 0.01559647600713876
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 6.65e-02  1.65e-03  1.77e-02 -9.78e-01  2.35e-02  1.51e-02
#    250| 3.51e-07  1.59e-06  1.69e-08 -9.87e-01  2.35e-02  1.30e+00
#    350| 5.01e-07  2.48e-07  1.74e-08 -9.87e-01  2.35e-02  1.82e+00
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.82e+00s = setup: 9.32e-05s + solve: 1.82e+00s
# 	 lin-sys: 3.17e-02s, cones: 1.77e+00s, accel: 2.61e-03s
# ------------------------------------------------------------------
# objective = -0.986551
# ------------------------------------------------------------------
# infid by SDP: 0.01344877252922716 iter: 350
# --- gamma = 0.099
# transpose infid direct: 0.015871504008431736
# transpose infid by choi: 0.015871504008431625
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 6.72e-02  1.66e-03  1.76e-02 -9.78e-01  2.35e-02  1.07e-02
#    250| 3.48e-07  1.63e-06  1.81e-08 -9.86e-01  2.35e-02  1.29e+00
#    325| 9.42e-07  2.62e-07  1.89e-08 -9.86e-01  2.35e-02  1.68e+00
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.68e+00s = setup: 7.10e-05s + solve: 1.68e+00s
# 	 lin-sys: 2.91e-02s, cones: 1.63e+00s, accel: 2.50e-03s
# ------------------------------------------------------------------
# objective = -0.986321
# ------------------------------------------------------------------
# infid by SDP: 0.01367901572222241 iter: 325
# --- gamma = 0.1
# transpose infid direct: 0.0161492156999401
# transpose infid by choi: 0.0161492156999401
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 6.78e-02  1.68e-03  1.76e-02 -9.78e-01  2.35e-02  1.31e-02
#    250| 3.44e-07  1.67e-06  1.93e-08 -9.86e-01  2.35e-02  1.29e+00
#    350| 8.34e-07  2.62e-07  1.98e-08 -9.86e-01  2.35e-02  1.81e+00
# ------------------------------------------------------------------
# status:  solved
# timings: total: 1.81e+00s = setup: 8.90e-05s + solve: 1.81e+00s
# 	 lin-sys: 3.18e-02s, cones: 1.76e+00s, accel: 2.66e-03s
# ------------------------------------------------------------------
# objective = -0.986089
# ------------------------------------------------------------------
# infid by SDP: 0.013910566880445785 iter: 350

# %%
plt.plot(np.linspace(0,0.1,101),scs_sol_infid1)
plt.ylabel("Infidelity")
plt.xlabel(r"$\gamma$")
plt.show()

# %%
plt.plot(np.linspace(0,0.1,101),scs_sol_iter1)
plt.ylabel("Iterations")
plt.xlabel(r"$\gamma$")
plt.show()

# %%
plt.title("Norm difference from previous solution")
plt.plot(np.linspace(0,0.1,101)[1:],np.array(sol_diff)[:,0],label="Primal")
plt.plot(np.linspace(0,0.1,101)[1:],np.array(sol_diff)[:,1],label="Dual")
plt.yscale('log')
plt.xlabel(r"$\gamma$")
plt.legend()
plt.show()

# %%
plt.scatter(range(len(all_sols[0]['y'])),np.where(np.abs(all_sols[1]['y'])<1e-4, np.nan, all_sols[1]['y']),label=r"$\gamma=0.001$")
plt.scatter(range(len(all_sols[0]['y'])),np.where(np.abs(all_sols[50]['y'])<1e-4, np.nan, all_sols[50]['y']),label=r"$\gamma=0.05$")
plt.scatter(range(len(all_sols[0]['y'])),np.where(np.abs(all_sols[-1]['y'])<1e-4, np.nan, all_sols[-1]['y']),label=r"$\gamma=0.1$")
plt.ylabel('Value y[i]')
plt.xlabel('Index i')
plt.legend()
